# %% [markdown]
# ### О задании
#
# Задание состоит из двух разделов, посвященных работе с табличными данными с помощью библиотеки `pandas` и визуализации с помощью `matplotlib`. В первом разделе вам предстоит выполнить базовые задания с помощью вышеуказанных библиотек, а во втором распределить студентов по курсам. Баллы даются за выполнение отдельных пунктов. Задачи в рамках одного раздела рекомендуется решать в том порядке, в котором они даны в задании.
#
# Задание направлено на освоение jupyter notebook (будет использоваться в дальнейших заданиях), библиотек pandas и matplotlib.
#
# ### Оценивание и штрафы
# Каждая из задач имеет определенную «стоимость» (указана в скобках около задачи). Максимально допустимая оценка за работу — 10 баллов без учёта бонусов.
#
#
# Оценка: xx.

# %% [markdown]
# ## 0. Введение

# %% [markdown]
# Сейчас мы находимся в jupyter-ноутбуке (или ipython-ноутбуке). Это удобная среда для написания кода, проведения экспериментов, изучения данных, построения визуализаций и других нужд, не связанных с написанием production-кода.
#
# Ноутбук состоит из ячеек, каждая из которых может быть либо ячейкой с кодом, либо ячейкой с текстом размеченным и неразмеченным. Текст поддерживает markdown-разметку и формулы в Latex.
#
# Для работы с содержимым ячейки используется *режим редактирования* (*Edit mode*, включается нажатием клавиши **Enter** после выбора ячейки), а для навигации между ячейками искользуется *командный режим* (*Command mode*, включается нажатием клавиши **Esc**). Тип ячейки можно задать в командном режиме либо с помощью горячих клавиш (**y** to code, **m** to markdown, **r** to edit raw text), либо в меню *Cell -> Cell type*.
#
# После заполнения ячейки нужно нажать *Shift + Enter*, эта команда обработает содержимое ячейки: проинтерпретирует код или сверстает размеченный текст.

# %%
# ячейка с кодом, при выполнении которой появится output
2 + 2
# Out:
# 4

# %% [markdown]
# Ячейка с неразмеченным текстом.

# %% [markdown]
# Попробуйте создать свои ячейки, написать какой-нибудь код и текст какой-нибудь формулой.

# %%
# your code
2+2*2
# Out:
# 6

# %% [markdown]
# [Здесь](https://athena.brynmawr.edu/jupyter/hub/dblank/public/Jupyter%20Notebook%20Users%20Manual.ipynb) находится <s>не</s>большая заметка о используемом языке разметки Markdown. Он позволяет:
#
# 0. Составлять упорядоченные списки
# 1. Выделять *текст* <s>при</s> **необходимости**
# 2. Добавлять [ссылки](http://imgs.xkcd.com/comics/the_universal_label.png)
#
#
# * Составлять неупорядоченные списки
#
# Делать вставки с помощью LaTex:
#
# $
# \left\{
# \begin{array}{ll}
# x = 16 \sin^3 (t) \\
# y = 13 \cos (t) - 5 \cos (2t) - 2 \cos (3t) - \cos (4t) \\
# t \in [0, 2 \pi]
# \end{array}
# \right.$

# %% [markdown]
# А ещё можно вставлять картинки, или гифки, или что захотите:
#
# <img src="https://media1.tenor.com/images/9b8fbe9214504bcf6c60fe4e4f7e114e/tenor.gif?itemid=5416416" style="width: 400px">

# %% [markdown]
# ### Google Colab

# %% [markdown]
# Что за колаб?
#
# **Google Colab (Colaboratory)** это **Jupyter Notebook + Cloud + Google Drive.**
#
# Компания Google предоставляет возможность бесплатно запускать ноутбуки (предварительно загрузив их на свой гугл-диск) прямо в облаке. При этом вам не требуется установка никаких пакетов на свою машину, а работать можно прямиком из браузера. Вот ссылка:

# %% [markdown]
# https://colab.research.google.com

# %% [markdown]
# При использовании вы увидите много сходств с jupyter ноутбуком. Одним из преимуществ является доступность GPU, соответствующую опцию можно активировать в настройках сервиса. При желании вы сможете найти в интернете много туториалов по использованию или разобраться самостоятельно

# %% [markdown]
# ### Kaggle
#
# Альтернативой является **Kaggle**, он же площадка для самых разных соревнований по машинному обучению
#
# Он, как и колаб, предоставляет бесплатный GPU, и даже не один, с чётким лимитом в 30 часов в неделю (colab может его внезапно отобрать, kaggle - нет) более мощные CPU с большим числом ядер, и больше Гб ОЗУ (раз так в 2.5)
#
# https://www.kaggle.com
#
# К сожалению мир не идеален, недостатки следующие:
# - необходимость загружать датасеты через специальную кнопочку
# - невозможность использовать свои скрипты и модули :(
# - нужно тыкать техподдержку, чтобы создать аккаунт из России

# %% [markdown]
# ## 1. Табличные данные и Pandas

# %% [markdown]
# Pandas — удобная библиотека для работы с табличными данными в Python, если данных не слишком много и они помещаются в оперативную память вашего компьютера. Несмотря на неэффективность реализации и некоторые проблемы, библиотека стала стандартом в анализе данных.
#
# Основной объект в `pandas` — это `pd.DataFrame`, представляющий собой таблицу с именованными колонками различных типов, индексом (может быть многоуровневым). DataFrame можно создавать, считывая таблицу из файла или задавая вручную из других объектов.
#
# В этой части потребуется выполнить несколько небольших заданий. Можно пойти двумя путями: сначала изучить материалы, а потом приступить к заданиям, или же разбираться "по ходу". Выбирайте сами.
#
# Материалы:
# 1. [Pandas за 10 минут из официального руководства](http://pandas.pydata.org/pandas-docs/stable/10min.html)
# 2. [Документация](http://pandas.pydata.org/pandas-docs/stable/index.html) (стоит обращаться, если не понятно, как вызывать конкретный метод)
# 3. [Примеры использования функционала](http://nbviewer.jupyter.org/github/justmarkham/pandas-videos/blob/master/pandas.ipynb)
#
# Многие из заданий можно выполнить несколькими способами. Не существуют единственно верного, но попробуйте максимально задействовать арсенал pandas и ориентируйтесь на простоту и понятность вашего кода. Мы не будем подсказывать, что нужно использовать для решения конкретной задачи, попробуйте находить необходимый функционал сами (название метода чаще всего очевидно). В помощь вам документация, поиск и StackOverflow.

# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Скачаем подготовленные данные:

# %%
# !wget  -O 'end_seminar.xlsx' -q 'https://www.dropbox.com/s/f4rm8sjc3v99p0m/_end_seminar.xlsx?dl=1'

# %% [markdown]
# Для пользователей Windows: скачайте файл самостоятельно и поместите его в папку с тетрадкой. Или попробуйте один из следующих вариантов:

# %%
# !powershell iwr -outf somefile https://somesite/somefile

# %%
# !pip install wget
# import wget
# wget.download('https://dropbox.com/s/f4rm8sjc3v99p0m/_end_seminar.xlsx?dl=1', 'end_seminar.xlsx')

# %% [markdown]
# ##### В первой части задания (до раздела "Распределение студентов по курсам") использование циклов запрещается и повлечет за собой снижение оценки. Использование <code>vectorize</code> и  <code>apply</code>, <code>apply_along_axis</code> и всего, где можно применить лямбда-функции (`assign`, `map`, ...) крайне нежелательно

# %% [markdown]
# Для каждой задачи из этого раздела вы должны написать код для получения ответа, а также дать текстовый ответ, если он предполагается.
#
# На некоторые вопросы вы можете получить путём пристального взгляда на таблицу, но это не будет засчитываться. Вы в любом случае должны получить ответ с помощью кода.

# %% [markdown]
# #### 1. [0.5 баллов] Откройте файл с таблицей (не забудьте про её формат). Выведите 3 последних строки.
#
# Посмотрите на данные и скажите, что они из себя представляют, сколько в таблице строк, какие столбцы? (на это не надо отвечать, просто подумайте об этом)

# %%
# your code
df = pd.read_excel('/content/end_seminar.xlsx')
df.tail(3)
# Out:
#                   timestamp                                id  rating  \
# 358 2020-05-20 11:54:38.318  d7118b44c7e8fdbbaaca226d2da6fef1    1111
# 359 2020-05-23 21:16:40.916  79d14db48e4737af731960ae212d5134     966
# 360 2020-05-23 21:16:40.916  f2d210ace25a841e1e58036b257d5d47    1195
#
#      18_group  is_mi                                           fall_1  \
# 358       NaN    NaN  Сбор и обработка данных с помощью краудсорсинга
# 359       NaN    NaN                 Безопасность компьютерных систем
# 360       NaN    NaN                Анализ неструктурированных данных
#
#                                                 fall_2  \
# 358                        Statistical Learning Theory
# 359  Принятие решений в условиях риска и неопределё...
# 360                      Моделирование временных рядов
#
#                                 fall_3  \
# 358  Анализ неструктурированных данных
# 359  Анализ неструктурированных данных
# 360  Высокопроизводительные вычисления
#
#                                               spring_1  \
# 358  Проектирование и разработка высоконагруженных ...
# 359  Проектирование и разработка высоконагруженных ...
# 360                           Обучение с подкреплением
#
#                                  spring_2  \
# 358  Методы сжатия и передачи медиаданных
# 359  Методы сжатия и передачи медиаданных
# 360                   Компьютерное зрение
#
#                                  spring_3 is_first_time  percentile  17_group  \
# 358                      Численные методы            Да    0.652174     173.0
# 359                   Компьютерное зрение            Да    0.985507     172.0
# 360  Методы сжатия и передачи медиаданных           NaN    0.369565     176.0
#
#                             blended  is_ml_student
# 358  Соревновательный анализ данных            NaN
# 359                          DevOps            NaN
# 360  Соревновательный анализ данных            NaN

# %% [markdown]
# ### Ответьте на вопросы:
# 1. Сколько было уникальных пользователей из групп 18-го года набора, а сколько из групп 17-го года?

# %%
# your code
print('18 год: ', df[df['18_group'].notna()]['id'].nunique())
print('17 год: ', df[df['17_group'].notna()]['id'].nunique())
# Out:
# 18 год:  213
# 17 год:  134

# %% [markdown]
# 2. Есть ли уникальные студенты с равными перцентилями?

# %%
# your code
percentile_count = df.groupby('percentile')['id'].nunique()
print(percentile_count[percentile_count > 1])
print("\n", df[df['percentile'] == 0]['id'])
# Out:
# percentile
# 0.0    2
# Name: id, dtype: int64
#
#  80     3e106aaef8b24dbb01319c73e14c2936
# 231    3a7326c9e355a67d3805824ca34c4bc5
# Name: id, dtype: object

# %% [markdown]
# #### 2. [0.5 балла] Есть ли в данных пропуски? В каких колонках? Сколько их в каждой из этих колонок?

# %%
# your code
df.isna().sum()
# Out:
# timestamp          0
# id                 0
# rating             0
# 18_group         138
# is_mi            343
# fall_1             0
# fall_2             0
# fall_3             0
# spring_1           0
# spring_2           0
# spring_3           0
# is_first_time      2
# percentile         0
# 17_group         223
# blended          223
# is_ml_student    304
# dtype: int64

# %% [markdown]
# Заполните пропуски пустой строкой для строковых колонок, нулём для числовых и False для булевых (постарайтесь избежать перечисления названий всех столбцов).

# %%
# your code
str_cols = df.select_dtypes(include = ['object']).columns
num_cols = df.select_dtypes(include = ['int64', 'float64']).columns
bool_cols = df.select_dtypes(include = ['bool']).columns

df[str_cols] = df[str_cols].fillna('')
df[num_cols] = df[num_cols].fillna(0)
df[bool_cols] = df[bool_cols].fillna(False)
df.isnull().sum()
# Out:
# timestamp        0
# id               0
# rating           0
# 18_group         0
# is_mi            0
# fall_1           0
# fall_2           0
# fall_3           0
# spring_1         0
# spring_2         0
# spring_3         0
# is_first_time    0
# percentile       0
# 17_group         0
# blended          0
# is_ml_student    0
# dtype: int64

# %% [markdown]
# #### 3. [0.5 балла] Посмотрите повнимательнее на колонку 'is_first_time'.
#
# Каково процентное соотношение ответов? Сколько из них "Нет"?

# %%
# your code
print('Нет:', round((df['is_first_time'] == 'Нет').sum()/df['is_first_time'].value_counts().sum() *100, 2))
print('Да:', 100 - round((df['is_first_time'] == 'Нет').sum()/df['is_first_time'].value_counts().sum() *100, 2))
# Out:
# Нет: 14.13
# Да: 85.87

# %% [markdown]
# Если вы найдете повторные обращения студентов, оставьте только самую позднюю версию. В дальнейших заданиях используйте версию данных без повторов.
#
# <i>Обращения со значением "Нет" в 'is_first_time' могут быть как повторными, так и первичными, поскольку поле заполняли сами студенты.</i>

# %%
# your code
df_sorted = df.sort_values('timestamp')
df = df_sorted.drop_duplicates(subset=['id'], keep='last')
df.shape
# Out:
# (347, 16)

# %% [markdown]
# #### 4. [0.5 балла] Какие  blended-курсы для четверокурсников существуют? На какой blended-курс записалось наибольшее количество студентов? На каком из blended-курсов собрались студенты с самым высоким средним рейтингом (выведите этот курс и количество студентов на нем)?

# %%
# your code
df.groupby("blended")["rating"].agg(["mean", "count"]).drop(index="").reset_index()
# Out:
#                                  blended         mean  count
# 0                                 DevOps  1154.172414     87
# 1  Введение в дифференциальную геометрию  1210.733333     15
# 2         Соревновательный анализ данных  1144.218750     32

# %% [markdown]
# #### 5. [1 балл] Выясните, есть ли студенты с абсолютно одинаковыми предпочтениями по всем курсам.
#
# Для этого сформируйте таблицу, где для каждого возможного набора курсов посчитано количество студентов, выбравших такой набор, и оставьте только строки где это количество больше 1.
#
# В данном случае набор курсов задается упорядоченным множеством ('fall_1', 'fall_2', 'fall_3', 'spring_1', 'spring_2', 'spring_3', 'blended'). Элемент blended будет нулевым для 3-го курса.

# %%
# your code
courses_columns = ['fall_1', 'fall_2', 'fall_3', 'spring_1', 'spring_2', 'spring_3', 'blended']

combination = df.groupby(courses_columns)['id'].count().reset_index()
combination = combination.rename(columns = {'id': 'student_count'})

combination = combination[combination['student_count'] > 1]
combination
# Out:
#                                               fall_1  \
# 0                        Statistical Learning Theory
# 60             Байесовские методы машинного обучения
# 62             Байесовские методы машинного обучения
# 72                  Безопасность компьютерных систем
# 84                  Безопасность компьютерных систем
# 102                 Безопасность компьютерных систем
# 105                 Безопасность компьютерных систем
# 113                 Безопасность компьютерных систем
# 137                 Безопасность компьютерных систем
# 155                 Безопасность компьютерных систем
# 184                Высокопроизводительные вычисления
# 201                Высокопроизводительные вычисления
# 244                    Моделирование временных рядов
# 292  Сбор и обработка данных с помощью краудсорсинга
# 313                                         Язык SQL
#
#                                               fall_2  \
# 0                  Анализ неструктурированных данных
# 60                 Анализ неструктурированных данных
# 62                 Анализ неструктурированных данных
# 72                       Statistical Learning Theory
# 84                 Высокопроизводительные вычисления
# 102                Высокопроизводительные вычисления
# 105                Высокопроизводительные вычисления
# 113                             Матричные вычисления
# 137  Сбор и обработка данных с помощью краудсорсинга
# 155                                Теория баз данных
# 184                 Безопасность компьютерных систем
# 201  Сбор и обработка данных с помощью краудсорсинга
# 244  Сбор и обработка данных с помощью краудсорсинга
# 292                                         Язык SQL
# 313                Высокопроизводительные вычисления
#
#                                               fall_3  \
# 0    Сбор и обработка данных с помощью краудсорсинга
# 60              Глубинное обучение в обработке звука
# 62   Сбор и обработка данных с помощью краудсорсинга
# 72                              Матричные вычисления
# 84                 Анализ неструктурированных данных
# 102                                         Язык SQL
# 105                                         Язык SQL
# 113                    Моделирование временных рядов
# 137                             Матричные вычисления
# 155                                         Язык SQL
# 184  Сбор и обработка данных с помощью краудсорсинга
# 201                    Моделирование временных рядов
# 244                 Безопасность компьютерных систем
# 292                                Теория баз данных
# 313                                Теория баз данных
#
#                                               spring_1  \
# 0                             Обучение с подкреплением
# 60                            Обучение с подкреплением
# 62                            Обучение с подкреплением
# 72                              Дискретная оптимизация
# 84   Проектирование и разработка высоконагруженных ...
# 102                                  Компьютерные сети
# 105        Промышленное программирование на языке Java
# 113        Промышленное программирование на языке Java
# 137                                  Компьютерные сети
# 155                                Машинное обучение 2
# 184  Проектирование и разработка высоконагруженных ...
# 201  Проектирование и разработка высоконагруженных ...
# 244                                  Компьютерные сети
# 292        Промышленное программирование на языке Java
# 313                                  Компьютерные сети
#
#                                         spring_2  \
# 0                         Конфликты и кооперация
# 60       Генеративные модели в машинном обучении
# 62                           Компьютерное зрение
# 72   Промышленное программирование на языке Java
# 84          Методы сжатия и передачи медиаданных
# 102  Промышленное программирование на языке Java
# 105                            Компьютерные сети
# 113                            Компьютерные сети
# 137  Промышленное программирование на языке Java
# 155                            Компьютерные сети
# 184         Методы сжатия и передачи медиаданных
# 201         Методы сжатия и передачи медиаданных
# 244   Дополнительные главы прикладной статистики
# 292                          Машинное обучение 2
# 313  Промышленное программирование на языке Java
#
#                                         spring_3 blended  student_count
# 0                            Компьютерное зрение  DevOps              2
# 60                           Компьютерное зрение  DevOps              2
# 62       Генеративные модели в машинном обучении  DevOps              2
# 72    Дополнительные главы прикладной статистики                      3
# 84                        Конфликты и кооперация  DevOps              2
# 102                       Дискретная оптимизация                      3
# 105                           Системы баз данных                      2
# 113                       Дискретная оптимизация                      2
# 137                      Анализ данных в бизнесе                      2
# 155  Промышленное программирование на языке Java                      2
# 184                          Компьютерное зрение  DevOps              2
# 201         Методы сжатия и передачи медиаданных  DevOps              2
# 244                           Системы баз данных                      2
# 292                            Компьютерные сети                      2
# 313                       Дискретная оптимизация                      2

# %% [markdown]
# #### 6. [0.5 балла] Найдите курсы по выбору, на которые записывались как студенты 18-го года набора, так и студенты 17-го года.

# %%
# your code
course_cols = ['fall_1', 'fall_2', 'fall_3', 'spring_1', 'spring_2', 'spring_3', 'blended']

courses_18 = (
    df.loc[df['18_group'] > 0, course_cols]
      .stack()
      .dropna()
      .astype(str)
      .str.strip()
      .str.lower()
)
courses_18 = set(courses_18[courses_18 != ''])

courses_17 = (
    df.loc[df['17_group'] > 0, course_cols]
      .stack()
      .dropna()
      .astype(str)
      .str.strip()
      .str.lower()
)
courses_17 = set(courses_17[courses_17 != ''])

common_courses = courses_18.intersection(courses_17)
common_courses
# Out:
# {'statistical learning theory',
#  'безопасность компьютерных систем',
#  'высокопроизводительные вычисления',
#  'моделирование временных рядов',
#  'принятие решений в условиях риска и неопределённости',
#  'сбор и обработка данных с помощью краудсорсинга',
#  'численные методы'}

# %% [markdown]
# Методом исключения найдите курсы, которые предлагались только студентам 18-го года и только студентам 17-го года.

# %%
# your code
only_18 = courses_18 - courses_17
only_17 = courses_17 - courses_18

print("Курсы только для 18-го года:", only_18)
print("Курсы только для 17-го года:", only_17)
# Out:
# Курсы только для 18-го года: {'компьютерные сети', 'системы баз данных', 'промышленное программирование на языке java', 'язык sql', 'дискретная оптимизация', 'теория баз данных', 'машинное обучение 2', 'анализ данных в бизнесе', 'дополнительные главы прикладной статистики', 'матричные вычисления'}
# Курсы только для 17-го года: {'конфликты и кооперация', 'методы сжатия и передачи медиаданных', 'анализ неструктурированных данных', 'введение в дифференциальную геометрию', 'соревновательный анализ данных', 'байесовские методы машинного обучения', 'devops', 'обучение с подкреплением', 'компьютерное зрение', 'проектирование и разработка высоконагруженных сервисов', 'символьные вычисления', 'глубинное обучение в обработке звука', 'генеративные модели в машинном обучении'}

# %% [markdown]
# ### Визуализации и matplotlib

# %% [markdown]
# При работе с данными часто неудобно делать какие-то выводы, если смотреть на таблицу и числа в частности, поэтому важно уметь визуализировать данные. Здесь будут описаны ключевые правила оформления графиков для **всех** домашних заданий.
#
# У matplotlib, конечно же, есть [документация](https://matplotlib.org/users/index.html) с большим количеством [примеров](https://matplotlib.org/examples/), но для начала достаточно знать про несколько основных типов графиков:
# - plot — обычный поточечный график, которым можно изображать кривые или отдельные точки;
# - hist — гистограмма, показывающая распределение некоторой величины;
# - scatter — график, показывающий взаимосвязь двух величин;
# - bar — столбцовый график, показывающий взаимосвязь количественной величины от категориальной.
#
# В этом задании вы попробуете построить один из них. Не забывайте про базовые принципы построения приличных графиков:
# - оси должны быть подписаны, причём не слишком мелко;
# - у графика должно быть название;
# - если изображено несколько графиков, то необходима поясняющая легенда;
# - все линии на графиках должны быть чётко видны (нет похожих цветов или цветов, сливающихся с фоном);
# - если отображена величина, имеющая очевидный диапазон значений (например, проценты могут быть от 0 до 100), то желательно масштабировать ось на весь диапазон значений (исключением является случай, когда вам необходимо показать малое отличие, которое незаметно в таких масштабах);
# - сетка на графике помогает оценить значения в точках на глаз, это обычно полезно, поэтому лучше ее отрисовывать;
# - если распределение на гистограмме имеет тяжёлые хвосты, лучше использовать логарифмическую шкалу.
#
# Еще одна билиотека для визуализации: [seaborn](https://jakevdp.github.io/PythonDataScienceHandbook/04.14-visualization-with-seaborn.html) (обычно сокращается до sns). Это настройка над matplotlib, иногда удобнее и красивее делать визуализации через неё.
#
# **5 пунктов после которых ваши графики не будут прежними:**
# - для красивой картинки <code>%config InlineBackend.figure_format = 'retina'</code>
# - задаем размер (почти) всех графиков (можно выбрать другие значения) <code>plt.rcParams['figure.figsize'] = 8, 5</code>
# - размер шрифта подписей графиков <code>plt.rcParams['font.size'] = 12</code>
# - формат в котором сохраняется изображение <code>mpl.rcParams['savefig.format'] = 'pdf'</code>
# - sns – seaborn, добавляет решетку <code>sns.set_style('darkgrid')</code>
#
# Добавьте эти функции в ячейку ниже. Каждый график все равно придется настраивать отдельно, но указанные строчки позволят значительно упростить процесс.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# your code
# %config InlineBackend.figure_format = 'retina'
plt.rcParams['figure.figsize'] = 8, 5
plt.rcParams['font.size'] = 12
mpl.rcParams['savefig.format'] = 'pdf'
sns.set_style('darkgrid')

# %% [markdown]
# #### 7. [0.5 балла] Постройте график средних рейтингов по дням получения ответов (bar plot).

# %%
# your code
df['day'] = df['timestamp'].dt.date
daily_rating = df.groupby('day')['rating'].mean()
daily_rating.plot(kind='bar')
plt.title("Средние рейтинги по дням получения ответов")
plt.xlabel("Дата ответа")
plt.ylabel("Средний рейтинг")
plt.xticks(rotation=45);
# Out:
# /tmp/ipython-input-3254257423.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['day'] = df['timestamp'].dt.date

# %% [markdown]
# Сохраните график в формате pdf (так он останется векторизованным).

# %%
# your code
df['day'] = df['timestamp'].dt.date
daily_rating = df.groupby('day')['rating'].mean()
daily_rating.plot(kind='bar')
plt.title("Средние рейтинги по дням получения ответов")
plt.xlabel("Дата ответа")
plt.ylabel("Средний рейтинг")
plt.xticks(rotation=45)

plt.savefig('average_rating_by_day.pdf', format = 'pdf', bbox_inches = 'tight')
plt.show();
# Out:
# /tmp/ipython-input-226224864.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['day'] = df['timestamp'].dt.date

# %% [markdown]
# ### 2. Распределение студентов по курсам.

# %% [markdown]
# <span style="color:red">!!!ВНИМАТЕЛЬНО ИЗУЧИТЕ ТЕКСТ НИЖЕ!!!</span>.
#
# <span style="color:orange">Если во время выполнения заданий у вас вознинут вопросы -- еще раз перечитайте текст целиком, скорее всего ответы уже содержатся в нем.</span>

# %% [markdown]
# Теперь вам нужно распределить студентов по осенним курсам по выбору, учитывая их предпочтения.

# %% [markdown]
# ## 📌 **Алгоритм распределения студентов по курсам**:
# 1. По умолчанию на каждой дисциплине по выбору у 3 и 4 курсов может учиться 1 группа (до 30 студентов). Исключения описаны ниже. На blended-дисциплинах для четверокурсников количество мест не ограничено.
# 2. Проводится первая волна отбора. Для каждой дисциплины формируется список тех, кто указал её первым приоритетом (если студент должен выбрать два курса по выбору, то для него дисциплины, которые он указал первым и вторым приоритетом, рассматриваются как дисциплины первого приоритета). Если желающих больше, чем мест, то выбирается топ по перцентилю рейтинга.
# 3. На дисциплинах, где остались места после первой волны, формируются списки тех, кто выбрал их вторым приоритетом, и места заполняются лучшими по перцентили рейтинга студентами. После этого проводится такая же процедура для дисциплин третьего приоритета.
# 4. Если студент не попал на необходимое количество курсов по итогам трёх волн, с ним связывается учебный офис и решает вопрос в индивидуальном порядке.

# %% [markdown]
# ## ☝️ **Обращаем ваше внимание на следующие детали:**
# - Конкурс на каждый курс общий для 3-го и 4-го курса
#
# - По умолчанию студент выбирает один осенний и один весенний курс по выбору, а также четверокурсники выбирают один blended-курс. Студенты групп 17-го года специализаций МОП и ТИ выбирают по 2 осенних и 2 весенних курса по выбору, также студенты групп 18' специализации МИ выбирают 2 осенних курса. <i>Для студентов, которые выбирают 2 курса (например, осенних) первый приоритет — <code>fall_1</code> и <code>fall_2</code>, второй приоритет — <code>fall_3</code>. Такие студенты участвуют только в двух волнах отбора</i>.
#
# - Студенты специализации МОП не могут выбрать весенним курсом по выбору Машинное обучение 2. **Если студент специализации МОП выбрал Машинное обучение 2, то его приоритеты сдвигаются.** Из-за совпадений первого и второго курса по выбору двигать приоритеты не надо.
#
# - Blended-курсы не трогайте, по ним не надо распределять, на другие курсы они никак не влияют.
#
# - Заведомо известно, что в процессе распределения не возникнет ситуации, когда на одно место претендуют студенты с одинаковым перцентилем.
#
# - Постарайтесь воздержаться от использования циклов там, где это возможно. <i>Допустимо итерироваться по <b>курсам</b>, на которые проводится отбор, и по <b>волнам</b> отбора. Если вы придумаете, как обойтись и без этих циклов, то на усмотрение проверяющего могут быть добавлены бонусные баллы. <b>Дублирование кода не признается успешным избавлением от циклов</b></i>
#
# - На выходе ожидается файл res_fall.csv с результатами распределения на осенние курсы по выбору. Файл должен быть следующего формата:
#
#     * Три колонки: ID, course1, course2
#
#     * Если студент не попал на курс, но должен был, то вместо названия курса в ячейке должна быть строка "???"
#
#     * Если студент должен выбрать только один курс, то в колонке course2 для него должна стоять строка "-"
#
#     * Если студент должен выбрать два курса по выбору, то порядок в колонках course1 и course2 не важен.
#
#     * hint: для сохранения воспользуйтесь `df.to_csv('solution.csv', index=None)`
#
#
# Для работы вам могут понадобиться следующие данные:
#
# - Результаты опроса (вы уже использовали этот файл в первой части задания, но на всякий случай ссылка: https://www.dropbox.com/s/f4rm8sjc3v99p0m/_end_seminar.xlsx?dl=0)
#
# - Соответствие номеров групп специализациям:
#
#     * 171, 172 - МОП; 173 - ТИ; 174 — АДИС; 175, 176 — РС; 177 — АПР
#
#     * У студентов 18-го года номера групп соответствуют номерам до распределения по специализациям. Это означает, что по номеру группы 18* нельзя однозначно определить специализацию студента. При этом в рамках распределения важно знать информацию только о двух из них: МОП и МИ. Эти знание можно получить из колонок 'is_ml_student
# ' и 'is_mi' соответственно.
#
# - Ограничения по количеству мест на курсах по выбору:
#
#     * Осенние: везде 30 мест, кроме Statistical Learning Theory (60 мест), Высокопроизводительных вычислений (60 мест), Анализа неструктурированных данных ($\infty$ мест)
#
#     * Весенние: везде 30 мест, кроме Обучения с подкреплением (60 мест), Анализа данных в бизнесе (60 мест).
#
#
# Кстати, убедитесь, что в данных больше нет пропусков и повторных записей.

# %% [markdown]
# #### 0. Проверка
#
# Для начала давайте убедимся, что вы успешно выполнили задания первой части и проверим ваши данные на наличие пропусков и повторов:

# %%
assert df.shape[0] == 347, 'В таблице остались повторы или потеряны данные'

assert df.isna().sum().sum() == 0, 'В таблице остались пропуски'

# %% [markdown]
# Если вы не получили AssertionError, то можете продолжать.

# %% [markdown]
# #### 1. [1 балл] Создайте новый признак, обозначающий, сколько осенних курсов должен выбрать студент
#
# В этом вам может помочь информация о специализации и группе стундента.

# %%
# (￣^￣)ゞ
df['fall_courses'] = 1
df.loc[(df['is_mi'] == 1) | df['17_group'].between(171, 173), 'fall_courses'] = 2
df
# Out:
# /tmp/ipython-input-1112766943.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['fall_courses'] = 1
#                   timestamp                                id  rating  \
# 223 2020-05-14 20:23:21.662  d555d2805e1d93d4f023e57dc4c8f403     996
# 224 2020-05-14 20:47:13.833  253bbe1a2021d0404712a1e4acd22939    1106
# 225 2020-05-14 20:52:42.734  881b1a6fda195b354ae2edb396a69f5d    1084
# 226 2020-05-14 21:03:02.916  5a9b8ac11ad05b39a58b0e04a263bf4c    1170
# 227 2020-05-14 21:10:54.945  1bbbfae51794b83c769b634be8da7b8d    1078
# ..                      ...                               ...     ...
# 220 2020-05-21 16:33:15.899  1341f488fae5f1ccf164960fd6506cd0     584
# 360 2020-05-23 21:16:40.916  f2d210ace25a841e1e58036b257d5d47    1195
# 359 2020-05-23 21:16:40.916  79d14db48e4737af731960ae212d5134     966
# 221 2020-05-24 01:21:31.946  04bcb5c9d23813ffa940e1febb27fadc     646
# 222 2020-05-24 01:23:31.946  9d19b0d5f4fc8d7edc2258406f872c4e     695
#
#      18_group  is_mi                                fall_1  \
# 223       0.0    0.0      Безопасность компьютерных систем
# 224       0.0    0.0      Безопасность компьютерных систем
# 225       0.0    0.0      Безопасность компьютерных систем
# 226       0.0    0.0  Глубинное обучение в обработке звука
# 227       0.0    0.0      Безопасность компьютерных систем
# ..        ...    ...                                   ...
# 220     188.0    0.0                              Язык SQL
# 360       0.0    0.0     Анализ неструктурированных данных
# 359       0.0    0.0      Безопасность компьютерных систем
# 221     186.0    0.0                     Теория баз данных
# 222     188.0    0.0      Безопасность компьютерных систем
#
#                                                 fall_2  \
# 223               Глубинное обучение в обработке звука
# 224                      Моделирование временных рядов
# 225                  Анализ неструктурированных данных
# 226                        Statistical Learning Theory
# 227                  Высокопроизводительные вычисления
# ..                                                 ...
# 220                                  Теория баз данных
# 360                      Моделирование временных рядов
# 359  Принятие решений в условиях риска и неопределё...
# 221                  Высокопроизводительные вычисления
# 222                                           Язык SQL
#
#                                               fall_3  \
# 223            Байесовские методы машинного обучения
# 224                      Statistical Learning Theory
# 225             Глубинное обучение в обработке звука
# 226  Сбор и обработка данных с помощью краудсорсинга
# 227                Анализ неструктурированных данных
# ..                                               ...
# 220                 Безопасность компьютерных систем
# 360                Высокопроизводительные вычисления
# 359                Анализ неструктурированных данных
# 221                 Безопасность компьютерных систем
# 222                Высокопроизводительные вычисления
#
#                                               spring_1  \
# 223                                Компьютерное зрение
# 224  Проектирование и разработка высоконагруженных ...
# 225                                Компьютерное зрение
# 226                             Конфликты и кооперация
# 227  Проектирование и разработка высоконагруженных ...
# ..                                                 ...
# 220        Промышленное программирование на языке Java
# 360                           Обучение с подкреплением
# 359  Проектирование и разработка высоконагруженных ...
# 221                                  Компьютерные сети
# 222                                  Компьютерные сети
#
#                                               spring_2  \
# 223                           Обучение с подкреплением
# 224                                   Численные методы
# 225  Проектирование и разработка высоконагруженных ...
# 226                           Обучение с подкреплением
# 227               Методы сжатия и передачи медиаданных
# ..                                                 ...
# 220                                  Компьютерные сети
# 360                                Компьютерное зрение
# 359               Методы сжатия и передачи медиаданных
# 221                             Дискретная оптимизация
# 222                             Дискретная оптимизация
#
#                                               spring_3 is_first_time  \
# 223  Проектирование и разработка высоконагруженных ...            Да
# 224               Методы сжатия и передачи медиаданных            Да
# 225            Генеративные модели в машинном обучении            Да
# 226            Генеративные модели в машинном обучении            Да
# 227                             Конфликты и кооперация            Да
# ..                                                 ...           ...
# 220                                 Системы баз данных            Да
# 360               Методы сжатия и передачи медиаданных
# 359                                Компьютерное зрение            Да
# 221                                Машинное обучение 2           Нет
# 222                                   Численные методы
#
#      percentile  17_group                         blended  is_ml_student  \
# 223    0.963768     172.0                          DevOps            0.0
# 224    0.673913     176.0                          DevOps            0.0
# 225    0.782609     172.0                          DevOps            0.0
# 226    0.442029     171.0                          DevOps            0.0
# 227    0.789855     176.0                          DevOps            0.0
# ..          ...       ...                             ...            ...
# 220    0.721973       0.0                                            0.0
# 360    0.369565     176.0  Соревновательный анализ данных            0.0
# 359    0.985507     172.0                          DevOps            0.0
# 221    0.430493       0.0                                            0.0
# 222    0.197309       0.0                                            0.0
#
#             day  fall_courses
# 223  2020-05-14             2
# 224  2020-05-14             1
# 225  2020-05-14             2
# 226  2020-05-14             2
# 227  2020-05-14             1
# ..          ...           ...
# 220  2020-05-21             1
# 360  2020-05-23             1
# 359  2020-05-23             2
# 221  2020-05-24             1
# 222  2020-05-24             1
#
# [347 rows x 18 columns]

# %% [markdown]
# Проверка:

# %%
col_name =   "fall_courses"  # insert your new column name as str

assert(df[df['id'] == '2662600c2c37e11e62f6ee0b88452f22'][col_name] == 2).all()
assert(df[df['id'] == 'd555d2805e1d93d4f023e57dc4c8f403'][col_name] == 2).all()
assert(df[df['id'] == '8fe79f84f36e3a5d2d6745621321302c'][col_name] == 1).all()
assert(df[df['id'] == 'e4caca755ee0bdd711e18fb8084958b5'][col_name] == 1).all()

# %% [markdown]
# #### 2. [2 балла] Распределите студентов в соответствии с первым приоритетом

# %%
df_fall_1 = df[["id", "fall_1", "fall_2", "percentile", "fall_courses"]]
df_fall_1.loc[df["fall_courses"] == 1, "fall_2"] = ""
df_fall_1 = df_fall_1.melt(id_vars=["id", "percentile"], value_vars=["fall_1", "fall_2"])\
    .sort_values(by=["percentile", "id"])

df_fall_1 = df_fall_1.drop(df_fall_1.loc[df_fall_1["value"] == ""].index)

df_fall_1
# Out:
#                                    id  percentile variable  \
# 8    3a7326c9e355a67d3805824ca34c4bc5    0.000000   fall_1
# 355  3a7326c9e355a67d3805824ca34c4bc5    0.000000   fall_2
# 141  3e106aaef8b24dbb01319c73e14c2936    0.000000   fall_1
# 155  e0ca1a9548af9a3f98428c62420aa484    0.004484   fall_1
# 114  7fe7df0d207babbf30249b3063ac1f26    0.007246   fall_1
# ..                                ...         ...      ...
# 691  79d14db48e4737af731960ae212d5134    0.985507   fall_2
# 261  40b18d40197e3db66312a026e06b8ff1    0.986547   fall_1
# 209  be4fa2120de3397ae21eac38ff0060e3    0.991031   fall_1
# 291  d539461bf254cf8b3201cdf7990b119e    0.992754   fall_1
# 338  7a21ef645ecb42198be493dd65320e78    0.995516   fall_1
#
#                                                  value
# 8                          Statistical Learning Theory
# 355                  Высокопроизводительные вычисления
# 141                   Безопасность компьютерных систем
# 155                               Матричные вычисления
# 114                  Высокопроизводительные вычисления
# ..                                                 ...
# 691  Принятие решений в условиях риска и неопределё...
# 261                   Безопасность компьютерных систем
# 209                   Безопасность компьютерных систем
# 291                  Анализ неструктурированных данных
# 338  Принятие решений в условиях риска и неопределё...
#
# [436 rows x 4 columns]

# %%
for i in df_fall_1["value"].unique():
    df_fall_1_temp = df_fall_1.loc[df_fall_1["value"] == i]\
        .groupby(["value", "id"])["percentile"]\
        .mean()\
        .sort_values()\
        .reset_index()

    stud_len = 0
    if i in ("Statistical Learning Theory", "Высокопроизводительные вычисления"):
        stud_len = 60
    elif i == "Анализ неструктурированных данных":
        stud_len = df_fall_1_temp.shape[0]
    else:
        stud_len = 30
    if stud_len > df_fall_1_temp.shape[0]:
        stud_len = df_fall_1_temp.shape[0]
    df_fall_1_temp = df_fall_1_temp.head(stud_len)

    df.loc[df_fall_1_temp.iloc[0]["id"] == df["id"],
        "is_first_place"] = True
    df.loc[df_fall_1_temp.iloc[stud_len-1]["id"] == df["id"],
        "is_last_place"] = True
# Out:
# /tmp/ipython-input-4010353892.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df_fall_1_temp.iloc[0]["id"] == df["id"],
# /tmp/ipython-input-4010353892.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df_fall_1_temp.iloc[stud_len-1]["id"] == df["id"],

# %% [markdown]
# Здесь для проверки приведена таблица, в которой есть 2 дополнительные колонки:
#
#     1) is_first_place - является ли студент лучшим по перцентили хотя бы на одном из курсов, куда он был зачислен
#     (True / NaN)
#
#     2) is_last_place  - является ли студент худшим по перцентили хотя бы на одном из курсов, куда он был зачислен (True / NaN)

# %%
# !wget  -O '2_task_check.csv' -q 'https://www.dropbox.com/s/v8o2zzq3iz5gc9w/_2_task_check.csv?dl=0'
check_df = pd.read_csv('2_task_check.csv')

# %%
df
# Out:
#                   timestamp                                id  rating  \
# 223 2020-05-14 20:23:21.662  d555d2805e1d93d4f023e57dc4c8f403     996
# 224 2020-05-14 20:47:13.833  253bbe1a2021d0404712a1e4acd22939    1106
# 225 2020-05-14 20:52:42.734  881b1a6fda195b354ae2edb396a69f5d    1084
# 226 2020-05-14 21:03:02.916  5a9b8ac11ad05b39a58b0e04a263bf4c    1170
# 227 2020-05-14 21:10:54.945  1bbbfae51794b83c769b634be8da7b8d    1078
# ..                      ...                               ...     ...
# 220 2020-05-21 16:33:15.899  1341f488fae5f1ccf164960fd6506cd0     584
# 360 2020-05-23 21:16:40.916  f2d210ace25a841e1e58036b257d5d47    1195
# 359 2020-05-23 21:16:40.916  79d14db48e4737af731960ae212d5134     966
# 221 2020-05-24 01:21:31.946  04bcb5c9d23813ffa940e1febb27fadc     646
# 222 2020-05-24 01:23:31.946  9d19b0d5f4fc8d7edc2258406f872c4e     695
#
#      18_group  is_mi                                fall_1  \
# 223       0.0    0.0      Безопасность компьютерных систем
# 224       0.0    0.0      Безопасность компьютерных систем
# 225       0.0    0.0      Безопасность компьютерных систем
# 226       0.0    0.0  Глубинное обучение в обработке звука
# 227       0.0    0.0      Безопасность компьютерных систем
# ..        ...    ...                                   ...
# 220     188.0    0.0                              Язык SQL
# 360       0.0    0.0     Анализ неструктурированных данных
# 359       0.0    0.0      Безопасность компьютерных систем
# 221     186.0    0.0                     Теория баз данных
# 222     188.0    0.0      Безопасность компьютерных систем
#
#                                                 fall_2  \
# 223               Глубинное обучение в обработке звука
# 224                      Моделирование временных рядов
# 225                  Анализ неструктурированных данных
# 226                        Statistical Learning Theory
# 227                  Высокопроизводительные вычисления
# ..                                                 ...
# 220                                  Теория баз данных
# 360                      Моделирование временных рядов
# 359  Принятие решений в условиях риска и неопределё...
# 221                  Высокопроизводительные вычисления
# 222                                           Язык SQL
#
#                                               fall_3  \
# 223            Байесовские методы машинного обучения
# 224                      Statistical Learning Theory
# 225             Глубинное обучение в обработке звука
# 226  Сбор и обработка данных с помощью краудсорсинга
# 227                Анализ неструктурированных данных
# ..                                               ...
# 220                 Безопасность компьютерных систем
# 360                Высокопроизводительные вычисления
# 359                Анализ неструктурированных данных
# 221                 Безопасность компьютерных систем
# 222                Высокопроизводительные вычисления
#
#                                               spring_1  \
# 223                                Компьютерное зрение
# 224  Проектирование и разработка высоконагруженных ...
# 225                                Компьютерное зрение
# 226                             Конфликты и кооперация
# 227  Проектирование и разработка высоконагруженных ...
# ..                                                 ...
# 220        Промышленное программирование на языке Java
# 360                           Обучение с подкреплением
# 359  Проектирование и разработка высоконагруженных ...
# 221                                  Компьютерные сети
# 222                                  Компьютерные сети
#
#                                               spring_2  \
# 223                           Обучение с подкреплением
# 224                                   Численные методы
# 225  Проектирование и разработка высоконагруженных ...
# 226                           Обучение с подкреплением
# 227               Методы сжатия и передачи медиаданных
# ..                                                 ...
# 220                                  Компьютерные сети
# 360                                Компьютерное зрение
# 359               Методы сжатия и передачи медиаданных
# 221                             Дискретная оптимизация
# 222                             Дискретная оптимизация
#
#                                               spring_3 is_first_time  \
# 223  Проектирование и разработка высоконагруженных ...            Да
# 224               Методы сжатия и передачи медиаданных            Да
# 225            Генеративные модели в машинном обучении            Да
# 226            Генеративные модели в машинном обучении            Да
# 227                             Конфликты и кооперация            Да
# ..                                                 ...           ...
# 220                                 Системы баз данных            Да
# 360               Методы сжатия и передачи медиаданных
# 359                                Компьютерное зрение            Да
# 221                                Машинное обучение 2           Нет
# 222                                   Численные методы
#
#      percentile  17_group                         blended  is_ml_student  \
# 223    0.963768     172.0                          DevOps            0.0
# 224    0.673913     176.0                          DevOps            0.0
# 225    0.782609     172.0                          DevOps            0.0
# 226    0.442029     171.0                          DevOps            0.0
# 227    0.789855     176.0                          DevOps            0.0
# ..          ...       ...                             ...            ...
# 220    0.721973       0.0                                            0.0
# 360    0.369565     176.0  Соревновательный анализ данных            0.0
# 359    0.985507     172.0                          DevOps            0.0
# 221    0.430493       0.0                                            0.0
# 222    0.197309       0.0                                            0.0
#
#             day  fall_courses is_first_place is_last_place
# 223  2020-05-14             2            NaN          True
# 224  2020-05-14             1            NaN           NaN
# 225  2020-05-14             2            NaN           NaN
# 226  2020-05-14             2            NaN           NaN
# 227  2020-05-14             1            NaN           NaN
# ..          ...           ...            ...           ...
# 220  2020-05-21             1            NaN           NaN
# 360  2020-05-23             1            NaN           NaN
# 359  2020-05-23             2            NaN           NaN
# 221  2020-05-24             1            NaN           NaN
# 222  2020-05-24             1            NaN           NaN
#
# [347 rows x 20 columns]

# %% [markdown]
# После распределения студентов в соответствии с первым приоритетом добавьте в свой датафрейм аналогичные признаки и запустите проверку:

# %%
fir_col_name = "is_first_place"     # insert name of your new column with is_first_place as str
last_col_name = "is_last_place"      # insert name of your new column with is_last_place as str


assert((df[df[fir_col_name].isna() == False][['id']].sort_values('id').reset_index(drop=True)
        ==
        check_df[check_df['is_first_place'].isna() == False][['id']].sort_values('id').reset_index(drop=True)
       ).id.values).all()


assert((df[df[last_col_name].isna() == False][['id']].sort_values('id').reset_index(drop=True)
       ==
       check_df[check_df['is_last_place'].isna() == False][['id']].sort_values('id').reset_index(drop=True)
      ).id.values).all()

# %% [markdown]
# #### 3. [2 балла] Проведите все три волны отбора студентов на курсы по выбору

# %%
# (￣^'￣)ゞ

# %% [markdown]
# **Отправьте свой файл res_fall.csv в ЭОС".**

# %% [markdown]
# ### 4. [1 балла] Распределите таким же образом студентов еще и на весенние курсы по выбору.
#
# Если ваш код был хорошо структурирован, то это не составит проблем.
#
# Если вы выполнили это задание, сдайте среди прочего файл res_spring.csv в таком же формате, как и res_fall.csv.

# %%
# (￣^'￣)ゞ

# %% [markdown]
# **Отправьте свой файл res_spring.csv в ЭОС.**

# %% [markdown]
# Вставьте картинку, описывающую ваш опыт выполнения этого задания:
